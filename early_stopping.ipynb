# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X,y=make_circles(n_samples=100,noise=0.1,random_state=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
model=Sequential()

model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=3500,verbose=0)

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 9s 950us/step

# %%
#Early Stoppping

# %%
model=Sequential()

model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback=EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 1s 88ms/step - loss: 0.6958 - accuracy: 0.4750 - val_loss: 0.6882 - val_accuracy: 0.5500
# Epoch 2/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6906 - val_accuracy: 0.5000
# Epoch 3/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6913 - accuracy: 0.5500 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 4/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6898 - accuracy: 0.5125 - val_loss: 0.6963 - val_accuracy: 0.4000
# Epoch 5/3500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6883 - accuracy: 0.5125 - val_loss: 0.6981 - val_accuracy: 0.3500
# Epoch 6/3500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6876 - accuracy: 0.5000 - val_loss: 0.7005 - val_accuracy: 0.3500
# Epoch 7/3500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6865 - accuracy: 0.5375 - val_loss: 0.7015 - val_accuracy: 0.4000
# Epoch 8/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6855 - accuracy: 0.5500 - val_loss: 0.7034 - val_accuracy: 0.4500
# Epoch 9/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6846 - accuracy: 0.5625 - val_loss: 0.7053 - val_accuracy: 0.4500
# Epoch 10/3500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6839 - accuracy: 0.5625 - val_loss: 0.7069 - val_accuracy: 0.4000
# Epoch 11/3500
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6831 - accuracy: 0.5625 - val_loss: 0.7080 - val_accuracy: 0.3500
# Epoch 12/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6824 - accuracy: 0.5750 - val_loss: 0.7097 - val_accuracy: 0.3500
# Epoch 13/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6817 - accuracy: 0.5625 - val_loss: 0.7109 - val_accuracy: 0.3500
# Epoch 14/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6809 - accuracy: 0.5750 - val_loss: 0.7119 - val_accuracy: 0.3500
# Epoch 15/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6803 - accuracy: 0.5750 - val_loss: 0.7130 - val_accuracy: 0.3500
# Epoch 16/3500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6797 - accuracy: 0.5625 - val_loss: 0.7144 - val_accuracy: 0.3500
# Epoch 17/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6790 - accuracy: 0.5625 - val_loss: 0.7156 - val_accuracy: 0.3500
# Epoch 18/3500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6785 - accuracy: 0.5625 - val_loss: 0.7171 - val_accuracy: 0.4000
# Epoch 19/3500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6781 - accuracy: 0.5625 - val_loss: 0.7184 - val_accuracy: 0.4000
# Epoch 20/3500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6775 - accuracy: 0.5625 - val_loss: 0.7189 - val_accuracy: 0.4500
# Epoch 21/3500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6768 - accuracy: 0.5625 - val_loss: 0.7189 - val_accuracy: 0.4500
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
